# %%
# *
# **
# ***
# ****
l="*"
for i in range(1,5):
    print(l*i,sep="")
# Out:
# *
# **
# ***
# ****

# %%
print("    *\n   * *\n  *   *\n *     *\n*       *\n *     *\n  *   *\n   * *\n    *", sep="\n")
# Out:
#     *
#    * *
#   *   *
#  *     *
# *       *
#  *     *
#   *   *
#    * *
#     *

# %%
def pattren(name,age,city):
    print(f"\nname|age|city")
    print(f"{name}|{age}|{city}")
pattren("aditya",18,"banglore")
pattren("govind",23,"nagpur")
# Out:
# name|age|city
# aditya|18|banglore
#
# name|age|city
# govind|23|nagpur
