# %%
# intershala Tranings
# lambda -->Anonymous function
a = int(input("enter a number"))
b = int(input("enter a number"))
c = int(input("enter a number"))
hello = lambda a , b , c:a + b + c
hello(a,b,c)
# Out:
# 6

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
c=int(input("enter a number"))
largest = lambda a,b,c:(a>b & a>c) or (b>a & b>c) or(c>a & c>b)
largest(a,b,c)
# Out:
# False

# %%
#if we include string in the input but finding sum of only integers
find_sum = lambda s: sum(map(int, filter(str.isdigit ,str(s))))
print(find_sum("1dfg9erg9erg1ergr"))

# %%
do_dsfse=lambda s: s + '!'
print(do_dsfse("hello"))
print(do_dsfse("wow"))

# %%
filter_nums=lambda s: ''.join([chr for chr in s if not chr.isdigit()])

print("filter_nums()",filter_nums("geegksofgod101"))

# %%
my_list=[1,2,3,4,5,6,7,8]
new_list=list(filter(lambda x: x % 2 != 0,my_list))
print(new_list)
print(my_list)

# %%
def cube(y):
    print("Finding cube of number:",y)
    return y * y * y
    
lambda_cube = lambda num: num ** 3

# Calling normal function
print("Invoking function defined with def keyword:")
print(cube(30))

# Calling lambda function
print("Invoking lambda function:")
print(lambda_cube(30))

# %%
year=int(input("enter number of days in year"))
leap=bool(lambda year:(year%100!=0 & year%4==0 or year%400==0 or False))
print(leap)

# %%
l=["1","34","6","-7","0","5","10","20"]
print("sorted numerically",sorted(l,key=lambda x:int(x)))
print("filtered positive integers",list(filter(lambda x: not (int(x) % 2 != 0 and int(x)<0),l)))
l=[1,2,4,345,33,325,32,3,3,3,3,435,2,2]
print("operation on the list by using map() function",list(map(lambda x:str(int(x)+10),l)))
# Out:
# sorted numerically ['-7', '0', '1', '5', '6', '10', '20', '34']
# filtered positive integers ['1', '34', '6', '0', '5', '10', '20']
# operation on the list by using map() function ['11', '12', '14', '355', '43', '335', '42', '13', '13', '13', '13', '445', '12', '12']
