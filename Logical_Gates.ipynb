# %%
a=10
b=20
print(a and b)
print(b and a)
# Out:
# 20
# 10

# %%
a=10
b=20
print(a or b)
print(b or a)
# Out:
# 10
# 20

# %%
a=True
b=False
print(not a)
print(not b)
# Out:
# False
# True

# %%
a=True
b=False
print(a and b)
print(b and a)
# Out:
# False
# False

# %%
a=True
b=False
print(a or b)
print(b or a)
# Out:
# True
# True
