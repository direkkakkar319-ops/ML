# %%
first_name = ["John", "Marry", "Bob"] 
last_name = ["Smith", "Joseph", "Smith"]
full_names = list(zip(first_name, last_name))
full_names
# Out:
# [('John', 'Smith'), ('Marry', 'Joseph'), ('Bob', 'Smith')]
