# %%
#sets
a={1,2,3,4,5,6,67,8,9,10}
print(a)
#adding elements in sets:
#1
a.update([77,88,99])
print(a)
#2
a.add(1222)
print(a)

#finding elements in array:
print("sexy" in a)
# Out:
# {1, 2, 3, 4, 5, 6, 67, 8, 9, 10}
# {1, 2, 3, 4, 5, 6, 67, 8, 9, 10, 99, 77, 88}
# {1, 2, 3, 4, 5, 6, 67, 8, 9, 10, 99, 1222, 77, 88}
# False

# %%
s={"apple","banana","cherry"}
print(s)

l={1,2,3,4,5}
print(l)

c={"red","green"}
print(c)

c.add("blue")
print(c)

c.remove("red")
print(c)
# Out:
# {'apple', 'banana', 'cherry'}
# {1, 2, 3, 4, 5}
# {'red', 'green'}
# {'blue', 'red', 'green'}
# {'blue', 'green'}

# %%
set1=set(["fgfgf", "gergerg", "egregrg", "ergergerg"])
print(set1)
for i in set1:
    print(i)
print("geeks" in set1)

# %%
#ADDING ELEMENTS IN SETS
s={1,2,3,4,5,6,7}
print(s)
s.update([8,9])
print(s)
s.add(12)
print(s)
