# %%
a=complex(input("enter a complex number"))
b=str(a)
a1=a.real
a2=a.imag
b1=int(a1)
b2=int(a2)
print(b1+b2)
# Out:
# 5

# %%
a=2+3j
print(a.real)
print(a.imag)
print(a)
print(type(a))
# Out:
# 2.0
# 3.0
# (2+3j)
# <class 'complex'>

# %%
a=complex(input("enter a number"))
print(f"complex number is: {a}")
print("imaginarty part",a.imag)
print("real part",a.real)
# Out:
# complex number is: (2+3j)
# imaginarty part 3.0
# real part 2.0
